# %%
import pandas as pd

df = pd.read_csv('data/AAPL_historical.csv')
print(f"AAPL data shape: {df.shape}")
print(df.head())
# Out:
# AAPL data shape: (752, 10)
#                         Date        Open        High         Low       Close  \
# 0  2022-06-27 00:00:00-04:00  140.446759  141.224293  138.744080  139.423187
# 1  2022-06-28 00:00:00-04:00  139.885768  141.155393  135.151721  135.269821
# 2  2022-06-29 00:00:00-04:00  135.289514  138.448820  134.511980  137.031555
# 3  2022-06-30 00:00:00-04:00  135.082848  136.185159  131.657801  134.561218
# 4  2022-07-01 00:00:00-04:00  133.891946  136.844577  133.517956  136.736313
#
#      Volume  Dividends  Stock Splits Symbol                     Date.1
# 0  70207900        0.0           0.0   AAPL  2022-06-27 00:00:00-04:00
# 1  67083400        0.0           0.0   AAPL  2022-06-28 00:00:00-04:00
# 2  66242400        0.0           0.0   AAPL  2022-06-29 00:00:00-04:00
# 3  98964500        0.0           0.0   AAPL  2022-06-30 00:00:00-04:00
# 4  71051600        0.0           0.0   AAPL  2022-07-01 00:00:00-04:00
